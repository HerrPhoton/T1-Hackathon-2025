# %%
import sys
sys.path.append("../..")

from src.dataset_tools import YOLODatasetRenamer

# %%
renamer = YOLODatasetRenamer(
    dataset_dir="../../datasets/hands",
    prefix="hands",
    dry_run=True,
)
renamer.run()
# Out:
# [DRY-RUN] Would rename: 0000000118_jpg.rf.6857603e0e8c5c8ee725812153403bb6.jpg -> hands_00001.jpg
# [DRY-RUN] Would rename: 0000000118_jpg.rf.6857603e0e8c5c8ee725812153403bb6.txt -> hands_00001.txt
# [DRY-RUN] Would rename: 0000000128_jpg.rf.6d1f326c0a1778d474b8ed4654ae2629.jpg -> hands_00002.jpg
# [DRY-RUN] Would rename: 0000000128_jpg.rf.6d1f326c0a1778d474b8ed4654ae2629.txt -> hands_00002.txt
# [DRY-RUN] Would rename: 0000000140_jpg.rf.0aacafb76ddad5cd159f4732a692baf1.jpg -> hands_00003.jpg
# [DRY-RUN] Would rename: 0000000140_jpg.rf.0aacafb76ddad5cd159f4732a692baf1.txt -> hands_00003.txt
# [DRY-RUN] Would rename: 0000000143_jpg.rf.70d7cd185307262c713ebd8f9cae4f1b.jpg -> hands_00004.jpg
# [DRY-RUN] Would rename: 0000000143_jpg.rf.70d7cd185307262c713ebd8f9cae4f1b.txt -> hands_00004.txt
# [DRY-RUN] Would rename: 0000000456_jpg.rf.58684a192bd6b0462dac9dd6aab3750f.jpg -> hands_00005.jpg
# [DRY-RUN] Would rename: 0000000456_jpg.rf.58684a192bd6b0462dac9dd6aab3750f.txt -> hands_00005.txt
# ...
