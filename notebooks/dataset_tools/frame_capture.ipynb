# %%
import sys
sys.path.append("../..")

import matplotlib.pyplot as plt

from src.dataset_tools.frame_capture import CameraFrameCapture

# %%
with CameraFrameCapture() as cap:
    print(cap.get_actual_properties())
# Out:
# (640, 480, 30.0)

# %%
with CameraFrameCapture() as cap:
    frame = cap.read()
    plt.imshow(frame)
    plt.axis('off')
    plt.show()

# %%
from ultralytics import solutions

# %%
isegment = solutions.InstanceSegmentation(
    model="../yolo11n-seg.pt",
)

with CameraFrameCapture() as cap:
    frame = cap.read()
    results = isegment(frame)

    plt.imshow(results.plot_im)
    plt.axis('off')
    plt.show()
# Out:
# Ultralytics Solutions:  {'source': None, 'model': '../yolo11n-seg.pt', 'classes': None, 'show_conf': True, 'show_labels': True, 'region': None, 'colormap': 21, 'show_in': True, 'show_out': True, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'figsize': (12.8, 7.2), 'blur_ratio': 0.5, 'vision_point': (20, 20), 'crop_dir': 'cropped-detections', 'json_file': None, 'line_width': 2, 'records': 5, 'fps': 30.0, 'max_hist': 5, 'meter_per_pixel': 0.05, 'max_speed': 120, 'show': False, 'iou': 0.7, 'conf': 0.25, 'device': None, 'max_det': 300, 'half': False, 'tracker': 'botsort.yaml', 'verbose': True, 'data': 'images'}
# 0: 480x640 6.4ms, 1 cell phone
# Speed: 76.3ms track, 6.4ms solution per image at shape (1, 3, 480, 640)
